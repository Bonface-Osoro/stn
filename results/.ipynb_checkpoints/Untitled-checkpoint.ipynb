# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
df = pd.read_csv("windtexter_results.csv")
df1 = df.groupby(['windtexter','interception_probability'])['iteration'].count()
df1.to_csv("grouped.csv")
df1
# Out:
# windtexter  interception_probability
# Baseline    0.2                          35
#             0.3                          70
#             0.4                         123
#             0.5                         159
#             0.6                         217
#             0.7                         156
#             0.8                         122
#             0.9                         118
# Full        0.6                          41
#             0.7                          81
#             0.8                         266
#             0.9                         612
# Partial     0.4                         156
#             0.5                         172
#             0.6                          37
#             0.7                         315
#             0.8                         163
#             0.9                         157
# Name: iteration, dtype: int64

# %%
df1 = pd.read_csv("grouped.csv")
df1.columns = ['windtexter', 'interception_probability','iteration']

long_data = pd.melt(df1,
    id_vars=['windtexter', 'interception_probability'],
    value_vars=['iteration'])

long_data.columns = ['windtexter', 'interception_probability', 'Metric', 'Value']
sns.set(font_scale=1)
plot=sns.barplot(x="windtexter", y='Value', linewidth=1.2, hue='interception_probability',
    palette=sns.color_palette("bright", 9),
    data=long_data)

# %%
df = pd.read_csv("windtexter_results.csv")
df1 = df.groupby(['windtexter','message_status','interception_probability'])['iteration'].count()
df1.to_csv("groupedd.csv")
df1 = pd.read_csv("groupedd.csv")
df1.columns = ['message_status','interception_probability', 'iteration']

long_data = pd.melt(df1,
    id_vars=['message_status', 'interception_probability'],
    value_vars=['iteration'])

long_data.columns = ['message_status', 'interception_probability', 'Metric', 'Value']
sns.set(font_scale=1)
plot=sns.barplot(x='message_status', y='Value', linewidth=1.2, hue='interception_probability',
    palette=sns.color_palette("bright", 9),
    data=long_data)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In [10], line 5
#       3 df1.to_csv("groupedd.csv")
#       4 df1 = pd.read_csv("groupedd.csv")
# ----> 5 df1.columns = ['message_status','interception_probability', 'iteration']
#       7 long_data = pd.melt(df1,
#       8     id_vars=['message_status', 'interception_probability'],
#       9     value_vars=['iteration'])
#      11 long_data.columns = ['message_status', 'interception_probability', 'Metric', 'Value']
#
# File ~/anaconda3/envs/np4d/lib/python3.10/site-packages/pandas/core/generic.py:5915, in NDFrame.__setattr__(self, name, value)
#    5913 try:
#    5914     object.__getattribute__(self, name)
# -> 5915     return object.__setattr__(self, name, value)
#    5916 except AttributeError:
#    5917     pass
#
# File ~/anaconda3/envs/np4d/lib/python3.10/site-packages/pandas/_libs/properties.pyx:69, in pandas._libs.properties.AxisProperty.__set__()
#
# File ~/anaconda3/envs/np4d/lib/python3.10/site-packages/pandas/core/generic.py:823, in NDFrame._set_axis(self, axis, labels)
#     821 def _set_axis(self, axis: int, labels: AnyArrayLike | list) -> None:
#     822     labels = ensure_index(labels)
# --> 823     self._mgr.set_axis(axis, labels)
#     824     self._clear_item_cache()
#
# File ~/anaconda3/envs/np4d/lib/python3.10/site-packages/pandas/core/internals/managers.py:230, in BaseBlockManager.set_axis(self, axis, new_labels)
#     228 def set_axis(self, axis: int, new_labels: Index) -> None:
#     229     # Caller is responsible for ensuring we have an Index object.
# --> 230     self._validate_set_axis(axis, new_labels)
#     231     self.axes[axis] = new_labels
#
# File ~/anaconda3/envs/np4d/lib/python3.10/site-packages/pandas/core/internals/base.py:70, in DataManager._validate_set_axis(self, axis, new_labels)
#      67     pass
#      69 elif new_len != old_len:
# ---> 70     raise ValueError(
#      71         f"Length mismatch: Expected axis has {old_len} elements, new "
#      72         f"values have {new_len} elements"
#      73     )
#
# ValueError: Length mismatch: Expected axis has 4 elements, new values have 3 elements

# %%
df.groupby('interception_probability')['iteration'].nunique()

# %%
for i in df.index: 
    x = df["interception_probability"].loc[i]
    if x
